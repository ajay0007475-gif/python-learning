# %% [markdown]
# # Data Structures in Python

# %% [markdown]
# #### Data structures in python are being used for storing the data in a structured format so that we can access the data and along with that we can perform all of the operations with these data structures that we can perfom in the case of databases as well like crud(Create. Read, Update, Delete) Operations

# %% [markdown]
# ## Types of data structure in python are :
#
# ### 1. List
# ### 2. Tuple
# ### 3. Set
# ### 4. Dictionary

# %% [markdown]
# ## The different types of data structures differs on this basis that in which specific format we want to store our data.
