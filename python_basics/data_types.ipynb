# %% [markdown]
# # Data Types

# %% [markdown]
# ## Data types are classification of the data that tells the compiler or the interpreter that what kind of value we can store into a variable and how much amount of memory will be consumed to store the data and the operations it can perform.

# %%
age = input("Enter the age: ")

# %%
age
# Out:
# '28'

# %%
print(type(age))
# Out:
# <class 'str'>

# %%
age2 = 'Hello'

# %%
age2
# Out:
# 'Hello'

# %%
age+age2
# Out:
# '28Hello'

# %%
a = str()

# %%
type(a)
# Out:
# str

# %% [markdown]
# # Different Type of Data Types

# %% [markdown]
# ## 1. int
#
# 2. str
# 3. bool
# 4. float

# %%
a = 28
type(a)
# Out:
# int

# %%
b = "Ajay"

# %%
type(b)
# Out:
# str

# %%
c = 3.14

# %%
type(c)
# Out:
# float

# %%
is_true = True

# %%
type(is_true)
# Out:
# bool

# %%
a = 7
b = 7
a == b
# Out:
# True

# %%
a = 34
b = 7
a == b
# Out:
# False
