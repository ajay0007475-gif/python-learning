# %% [markdown]
# # What is Python Language ?

# %% [markdown]
# ## Python is a Type of programming Language which we can use for communicating with computers or technology

# %% [markdown]
# # Syntax for Python Language

# %% [markdown]
# Syntax refer to the set of rules that defines the combination of symbols that are considered to be correctly structured programs in a language.

# %% [markdown]
# # Semantics of Python Language

# %% [markdown]
# ## Semantics of python language refers to the meaning or interpretation of symbols, characters and commands in a language. It is about what code is supposed todo when it runs.

# %% [markdown]
# # Python Syntax Rules

# %% [markdown]
# ## 1. Python is case sensitive

# %%
name = "Amit"
Name = "Amit"
name == Name
# Out:
# True

# %%
name = "Amit"
Name = "amit"
name == Name
# Out:
# False

# %% [markdown]
# # Indentation in Python

# %% [markdown]
# ## In other programming language , we use {} for grouping of statements
# ## In python, we use Indentation for proper grouping of statements as per the proper arrangement of statements within a block.

# %%
age = int(input("Enter your age: "))
if age > 18 :
    print("You are eligible for driving")
# Out:
# You are eligible for driving

# %%
age = int(input("Enter your age: "))
if age > 18 :
print("You are eligible for driving")
# Out:
#   Cell In[4], line 3
#     print("You are eligible for driving")
#     ^
# IndentationError: expected an indented block after 'if' statement on line 2

# %%
1+2+3+4+5+6
# Out:
# 21

# %%
1+2+3+4+5+\
6+7
# Out:
# 28

# %% [markdown]
# ## Line Continuation---> We use  Backslash for continuing the statements on the next line

# %% [markdown]
# # Multiple Statements in a single line in Python

# %%
a=5;
b=6;

# %%
a=5 b=6
# Out:
#   Cell In[10], line 1
#     a=5 b=6
#         ^
# SyntaxError: invalid syntax

# %%
a=5; b=6;
