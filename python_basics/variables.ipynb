# %% [markdown]
# # Variables

# %% [markdown]
# ## Variables are the elements in python that can be used for storing data into it or values into it  or they can referred as containers as well.
# ## variables as per its name, data can vary  that we are going to store into it and once we have declared a variable we can scary the value stored in it.

# %%
age = 23
Name = "Ajay"
Height = 5.7
is_true = True

# %%
age
# Out:
# 23

# %%
Height
# Out:
# 5.7

# %%
Name
# Out:
# 'Ajay'

# %% [markdown]
# # print()

# %% [markdown]
# ## print() ---> print function is being used to represent the value that we are going to pass inside it.

# %%
print(age)
# Out:
# 23

# %%
print(Name)
# Out:
# Ajay

# %%
print("Name is: ", Name)
# Out:
# Name is:  Ajay

# %%
print("Age is: ", age)
# Out:
# Age is:  23

# %% [markdown]
# ## Comment
# ## Comment is the statement in a program that we dont want the interpreter to execute
# ## Interpreter  ---> execute the code line by line in python language
# ## Compiler --> executes the code completely

# %%
# Hello i am explaining about how to write comments in python programming language. Comments are used to explain the code and make it more readable. In python, we can write comments using the # symbol. Anything written after the # symbol is considered a comment and is ignored by the python interpreter. Comments are very useful for documenting your code and making it easier for others to understand.

# %%
# hello everything

# %%
'''
This is a multi-line comment in python. We can write multiple lines of comments using triple quotes'''
# Out:
# '\nThis is a multi-line comment in python. We can write multiple lines of comments using triple quotes'

# %% [markdown]
# ## Variables Naming Convention

# %%
''' Variables names must be Descriptive : 
    Age = 23
    Name 'Ajay'
    '''
# Out:
# " Variables names must be Descriptive : \n    Age = 23\n    Name 'Ajay'\n    "

# %%
''' They must start with a letter or an underscore and contain letters, numbers and underscores.'''
# Out:
# ' They must start with a letter or an underscore and contain letters, numbers and underscores.'

# %%
1name = "Ajay"
# Out:
#   Cell In[19], line 1
#     1name = "Ajay"
#     ^
# SyntaxError: invalid decimal literal

# %%
name1 = "Ajay"

# %%
_name = "Ajay"

# %%
''' 
variable  are also case sensitive. 
'''
# Out:
# ' \nvariable  are also case sensitive. \n'

# %%
name  = "Ajay"
Name = "Ajay"
name == Name
# Out:
# True

# %%
Age = 23
Name= "Ajay"
Height = 5.7
is_true = True

# %%
print(type(age))
# Out:
# <class 'int'>

# %%
print(Age)
# Out:
# 23

# %%
Age = 45

# %%
print(Age)
# Out:
# 45

# %%
Age = 23
print(type(age))
# Out:
# <class 'int'>

# %%
Age = str(Age)
print(Age)
print(type(Age))
# Out:
# 23
# <class 'str'>

# %%
Name = "Ajay"
Name = int(Name)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[40], line 2
#       1 Name = "Ajay"
# ----> 2 Name = int(Name)
#
# ValueError: invalid literal for int() with base 10: 'Ajay'

# %%
'''
Every type casting is not possible 
int --> str is possible
str --> int is not possible
'''
# Out:
# '\nEvery type casting is not possible \nint --> str is possible\nstr --> int is not possible\n'

# %% [markdown]
# # input()
# ## input() can take the input from the user side and then can store that into a variable

# %%
Name = input("Enter your name: ")

# %%
print(Name)
# Out:
# Ajay Sharma

# %% [markdown]
# ## Input function only takes the input in a string format until and ubnless we are not going to explicitly take the input in integer  or other format

# %%
Age = input("Enter your age: ")

# %%
print(Age)
print(type(Age))
# Out:
# 28
# <class 'str'>

# %%
Age = int(input("Enter your age: "))
print(Age)
print(type(Age))
# Out:
# 23
# <class 'int'>

# %%
Age =float(input("Enter your age: "))
print(Age)
print(type(Age))
# Out:
# 28.0
# <class 'float'>

# %%
Value =bool(input("Enter your age: "))
print(Value)
print(type(Value))
# Out:
# True
# <class 'bool'>

# %%
Value_user =bool(input("Enter your age: "))

# %%
Value_user
# Out:
# True

# %%
## building a Simple Calculator

value_1 = int(input("Enter first value: "))
value_2 = int(input("Enter second value: "))
print("first value from user is: ", value_1)
print("second value from user is: ", value_2)
print("The addition of two values is: ", value_1 + value_2)
print("The subtraction of two values is: ", value_1 - value_2)
print("The multiplication of two values is: ", value_1 * value_2)
print("The division of two values is: ", value_1 / value_2)
# Out:
# first value from user is:  10
# second value from user is:  15
# The addition of two values is:  25
# The subtraction of two values is:  -5
# The multiplication of two values is:  150
# The division of two values is:  0.6666666666666666
